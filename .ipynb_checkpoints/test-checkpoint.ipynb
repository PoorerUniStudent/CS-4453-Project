# %%
# %pip install swig
# %pip install "gymnasium[box2d]"

# %%
import gymnasium as gym

env = gym.make("CarRacing-v3", render_mode="human")
obs, info = env.reset()

for _ in range(2000):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 for _ in range(2000):
#       7     action = env.action_space.sample()
# ----> 8     obs, reward, terminated, truncated, info = env.step(action)
#       9     if terminated or truncated:
#      10         obs, info = env.reset()
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/envs/box2d/car_racing.py:562, in CarRacing.step(self, action)
#     559 self.world.Step(1.0 / FPS, 6 * 30, 2 * 30)
#     560 self.t += 1.0 / FPS
# --> 562 self.state = self._render("state_pixels")
#     564 step_reward = 0
#     565 terminated = False
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/envs/box2d/car_racing.py:657, in CarRacing._render(self, mode)
#     655     return self._create_image_array(self.surf, (VIDEO_W, VIDEO_H))
#     656 elif mode == "state_pixels":
# --> 657     return self._create_image_array(self.surf, (STATE_W, STATE_H))
#     658 else:
#     659     return self.isopen
#
# File ~/anaconda3/lib/python3.11/site-packages/gymnasium/envs/box2d/car_racing.py:788, in CarRacing._create_image_array(self, screen, size)
#     787 def _create_image_array(self, screen, size):
# --> 788     scaled_screen = pygame.transform.smoothscale(screen, size)
#     789     return np.transpose(
#     790         np.array(pygame.surfarray.pixels3d(scaled_screen)), axes=(1, 0, 2)
#     791     )
#
# KeyboardInterrupt:
